# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramprashanth17/Everything-Python/blob/main/DSA/219_Contains_Duplicate_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Given an integer array nums and an integer k, return true if there are two distinct indices i and j in the array such that nums[i] == nums[j] and abs(i - j) <= k.**
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,1], k = 3
#
# Output: true

# %%
class Solution:
    def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
        s = {}
        for i in range(len(nums)):
            if nums[i] in s and abs(i-s[nums[i]]) <=k:
                return True
            s[nums[i]]=i
        return False

# %%
class Solution:
    def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
        s = {}
        for i in range(len(nums)):
            if nums[i] in s and abs(i-s[nums[i]]) <=k:
                return True
            s[nums[i]]=i
        return False

# %%
class Solution:
    def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
        s = {}
        for i in range(len(nums)):
            if nums[i] in s and abs(i-s[nums[i]]) <=k:
                return True
            s[nums[i]]=i
        return False
